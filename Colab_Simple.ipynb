# %% [markdown]
# # YouTube Relaxing Video Generator
# Simples e direto - sem erros

# %%
print('Testando FFmpeg...'); import subprocess; subprocess.run(['ffmpeg','-version'], capture_output=True); print('FFmpeg OK')

# %%
from pathlib import Path; OUTPUT = Path('/content/output'); OUTPUT.mkdir(exist_ok=True); print('Pasta:', OUTPUT)

# %%
import subprocess; VIDEO = OUTPUT / 'test.mp4'; cmd = ['ffmpeg','-y','-f','lavfi','-i','color=c=blue:s=640x480:d=5','-t','5',str(VIDEO)]; subprocess.run(cmd); print('Video:', VIDEO.exists())

# %%
from google.colab import files; files.download(str(VIDEO))
